# %% [markdown]
# Task 2:

# %%
import numpy as np
import scipy.linalg

# %%
a = np.array([[1, 2], [0.1, -0.1], [3, 4]])
p = [10]; q = [20]; r = [30]; s = [40]
b = np.array([[10, 20], [-10, -20], [-3, -4]])
c = [[1, 0, 0], [0, 0, 0]]
v = np.array([0.4, 0.6])


# display(np.ndim(a))
# display(np.size(a))
# display(np.shape(a))
# display(a.shape[0])
# display(np.array([[1., 2., 3.], [4., 5., 6.]]))
# display(np.block([[p, q], [r, s]]))
# display(a[-1])
# display(a[1, 0])
# display(a[1])
# display(a[0:1])
# display(a[-1:])
# display(a[:, 0:2])
# display(a[np.ix_([1, 1, 0], [0, 1])])
# display(a[0:2:2, :])
# display(a[::2, :])
# display(a[np.r_[:len(a),0]])
# display(a.transpose())
# display(a.conj().transpose())
# display(a@c)
# display(a*b)
# display(a/b)
# display(a**3)
# display(a>0.5)
# display(np.nonzero(a>0.5))
# display(a[:,np.nonzero(v > 0.5)[0]])
# display(a[:,np.nonzero(v.transpose() > 0.5)[0]])
# a[a<0.5]=0; display(a)
# display(a * (a>0.5))
# b[:]=3; display(b)
# y=a.copy(); display(y)
# y = a[1, :].copy(); display(y)
# y = a.flatten(); display(y)
# display(np.arange(1., 11.))
# display(np.arange(10.))
# display(np.arange(1.,11.)[:, np.newaxis])
# display(np.zeros((3, 4)))
# display(np.zeros((3, 4, 5)))
# display(np.ones((3, 4)))
# display(np.eye(3))
# display(np.diag(a))
# display(np.diag(v, 0))
# from numpy.random import default_rng; rng = default_rng(42); display(rng.random((3, 4)))
# display(np.linspace(1,3,4))
# display(np.mgrid[0:9.,0:6.]	)
# display(np.meshgrid([1,2,4],[2,4,5]))
# display(np.ix_([1,2,4],[2,4,5]))
# display(np.tile(a, (1, 2)))
# display(np.concatenate((a,b),1))
# display(np.concatenate((a,b)))
# display(a.max())
# display(a.max(0))
# display(a.max(1))
# display(np.maximum(a, b))
# display(np.linalg.norm(v))
# display(np.logical_and(a,b))
# display(np.logical_or(a,b))
# display(0 & 20)
# display(0 | 20)

# %%
import scipy.linalg as linalg

a = np.array([[1,2,3],[4,5,6],[0,0,1]])
b = np.array([[1,0,0], [0,1,0], [0,0,1]])

linalg.inv(a)
linalg.pinv(c)
np.linalg.matrix_rank(a)
linalg.lstsq(a, b)
linalg.lstsq(a.transpose(), b.transpose())
U, S, Vh = linalg.svd(a); V = Vh.T; print(f"U={U}\n"); print(f"S={S}\n"); print(f"V={V}\n")	
linalg.cholesky(b)
D,V = linalg.eig(a)
D,V = linalg.eig(a, b)	
#D,V = linalg.eigs(a, k=3) #AttributeError: module 'scipy.linalg' has no attribute 'eigs'
Q,R = linalg.qr(a)	
P,L,U = linalg.lu(a)
#linalg.cg(a, b) #AttributeError: module 'scipy.linalg' has no attribute 'cg'	
np.fft.fft(a)
np.fft.ifft(a)
np.sort(a)
np.sort(a, axis=1)	
I = np.argsort(a[:, 0]); b = a[I,:]
x = linalg.lstsq(a, b)
# Out:
# U=[[-0.38559205  0.66666667 -0.63786701]
#  [-0.91967723 -0.33333333  0.20756366]
#  [-0.07424656  0.66666667  0.74164884]]
#
# S=[9.53420113 1.         0.31465667]
#
# V=[[-0.42628648 -0.66666667  0.6114208 ]
#  [-0.56319037 -0.33333333 -0.75611209]
#  [-0.70788166  0.66666667  0.23336476]]

# %% [markdown]
# Task 3:

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,2,7,14])
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# Task 4:

# %%
x = np.linspace(-10, 10, 100)
y = np.exp(-x**2)

plt.plot(x, y)
plt.show()
